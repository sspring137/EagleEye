# %% [markdown]
# #  EagleEye_v7 tutorial

# %% [markdown]
# We import necessary libraries and set up custom plot configurations for consistency.

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Directory setup for custom modules
import sys
module_path = '../../eagleeye'
sys.path.append(module_path)
import EagleEye_v7

# Custom plotting settings
sns.set(style="darkgrid")
plt.rcParams.update({
    'axes.titlesize': 21,
    'axes.labelsize': 17,
    'xtick.labelsize': 17,
    'ytick.labelsize': 17,
    'legend.fontsize': 17,
    'axes.grid': True,
    'grid.alpha': 0.3,
    'grid.linestyle': '--',
    'grid.color': 'gray'
})

# %% [markdown]
# ## 1. Generate the datasets

# %%
from utils_37 import generate_uniform_with_Gaussian_ove_under

# Generate data with anomalies
num_points = 50000
anomaly_sizes_o = [50, 100, 200, 300, 500, 700, 900]
anomaly_sizes_u = [ 100, 300, 700, ]
n_dim = 3

reference_data, test_data = generate_uniform_with_Gaussian_ove_under(n_dim, num_points, anomaly_sizes_o, anomaly_sizes_u)

# %% [markdown]
# ### 1.1 Visualize the generated datasets

# %%
from utils_37 import plot_injected_anomalies_in_uniform_background

# plot of the generated dataset. In silver the background only
# in red the injected overdensities and in blue the injected underdensities
plot_injected_anomalies_in_uniform_background(reference_data, anomaly_sizes_u, test_data, anomaly_sizes_o)

# %% [markdown]
# ## 2. EagleEye_v7

# %% [markdown]
# Reference dataset: $\mathbf{X}$
#
# Test dataset:      $\mathbf{Y}$
#
# Define: $\mathbf{U} = \mathbf{X} \cup \mathbf{Y}$
#
# COMPUTE: $\forall i\in U,$  $\Upsilon_i $ whith Inject validation for the data belonging to $\mathbf{X}$
#
# Revert the order of Reference and Test to get $\forall j\in U,$  $\Upsilon_{j}(rev) $ whith Inject validation for the data belonging to $\mathbf{Y}$

# %%
K_M                   = 500
CRITICAL_QUANTILES    = [ 1-1E-4, 1-1E-5 ]
VALIDATION            = reference_data.shape[0]


NUM_CORES             = 10

result_dictionary     = EagleEye_v7.Soar(
    reference_data, test_data, result_dict_in = {}, K_M = K_M, critical_quantiles = CRITICAL_QUANTILES,
    num_cores=NUM_CORES, validation=VALIDATION, partition_size=100 )
# Out:
# Eagle...Soar!
#
#                                /T /I
#                               / |/ | .-~/
#                           T\ Y  I  |/  /  _
#          /T               | \I  |  I  Y.-~/
#         I l   /I       T\ |  |  l  |  T  /
#      T\ |  \ Y l  /T   | \I  l   \ `  l Y
#  __  | \l   \l  \I l __l  l   \   `  _. |
#  \ ~-l  `\   `\  \  \ ~\  \   `. .-~   |
#   \   ~-. "-.  `  \  ^._ ^. "-.  /  \   |
# .--~-._  ~-  `  _  ~-_.-"-." ._ /._ ." ./
#  &gt;--.  ~-.   ._  ~&gt;-"    "\   7   7   ]
# ^.___~"--._    ~-{  .-~ .  `\ Y . /    |
#  &lt;__ ~"-.  ~       /_/   \   \I  Y   : |
#    ^-.__           ~(_/   \   &gt;._:   | l______
#        ^--.,___.-~"  /_/   !  `-.~"--l_ /     ~"-.
#               (_/ .  ~(   /'     "~"--,Y   -=b-. _)
#                (_/ .  \  :           / l      c"~o \
#                 \ /    `.    .     .^   \_.-~"~--.  )
#                  (_/ .   `  /     /       !       )/
#                   / / _.   '.   .':      /        '
#                   ~(_/ .   /    _  `  .-&lt;_
#                     /_/ . ' .-~" `.  / \  \          ,z=.
#                     ~( /   '  :   | K   "-.~-.______//
#                       "-,.    l   I/ \_    __{---&gt;._(==.
#                        //(     \  &lt;    ~"~"     //
#                       /' /\     \  \     ,v=.  ((
#                     .^. / /\     "  }__ //===-  `
#                    / / ' '  "-.,__ {---(==-
#                  .^ '       :  T  ~"   ll
#                 / .  .  . : | :!        \
#                (_/  /   | | j-"          ~^
#                  ~-&lt;_(_.^-~"
# Critical quantiles detected. Computing null distribution!
# Compute overdensities
# Validation size is:  50000
# Computed p-values for k=20
# Computed p-values for k=21
# Computed p-values for k=22
# Computed p-values for k=23
# Computed p-values for k=24
# Computed p-values for k=25
# Computed p-values for k=26
# Computed p-values for k=27
# Computed p-values for k=28
# Computed p-values for k=29
# Computed p-values for k=30
# Computed p-values for k=31
# Computed p-values for k=32
# Computed p-values for k=33
# Computed p-values for k=34
# Computed p-values for k=35
# Computed p-values for k=36
# Computed p-values for k=37
# Computed p-values for k=38
# Computed p-values for k=39
# Computed p-values for k=40
# Computed p-values for k=41
# Computed p-values for k=42
# Computed p-values for k=43
# Computed p-values for k=44
# Computed p-values for k=45
# Computed p-values for k=46
# Computed p-values for k=47
# Computed p-values for k=48
# Computed p-values for k=49
# Computed p-values for k=50
# Computed p-values for k=51
# Computed p-values for k=52
# Computed p-values for k=53
# Computed p-values for k=54
# Computed p-values for k=55
# Computed p-values for k=56
# Computed p-values for k=57
# Computed p-values for k=58
# Computed p-values for k=59
# Computed p-values for k=60
# Computed p-values for k=61
# Computed p-values for k=62
# Computed p-values for k=63
# Computed p-values for k=64
# Computed p-values for k=65
# Computed p-values for k=66
# Computed p-values for k=67
# Computed p-values for k=68
# Computed p-values for k=69
# Computed p-values for k=70
# Computed p-values for k=71
# Computed p-values for k=72
# Computed p-values for k=73
# Computed p-values for k=74
# Computed p-values for k=75
# Computed p-values for k=76
# Computed p-values for k=77
# Computed p-values for k=78
# Computed p-values for k=79
# Computed p-values for k=80
# Computed p-values for k=81
# Computed p-values for k=82
# Computed p-values for k=83
# Computed p-values for k=84
# Computed p-values for k=85
# Computed p-values for k=86
# Computed p-values for k=87
# Computed p-values for k=88
# Computed p-values for k=89
# Computed p-values for k=90
# Computed p-values for k=91
# Computed p-values for k=92
# Computed p-values for k=93
# Computed p-values for k=94
# Computed p-values for k=95
# Computed p-values for k=96
# Computed p-values for k=97
# Computed p-values for k=98
# Computed p-values for k=99
# Computed p-values for k=100
# Computed p-values for k=101
# Computed p-values for k=102
# Computed p-values for k=103
# Computed p-values for k=104
# Computed p-values for k=105
# Computed p-values for k=106
# Computed p-values for k=107
# Computed p-values for k=108
# Computed p-values for k=109
# Computed p-values for k=110
# Computed p-values for k=111
# Computed p-values for k=112
# Computed p-values for k=113
# Computed p-values for k=114
# Computed p-values for k=115
# Computed p-values for k=116
# Computed p-values for k=117
# Computed p-values for k=118
# Computed p-values for k=119
# Computed p-values for k=120
# Computed p-values for k=121
# Computed p-values for k=122
# Computed p-values for k=123
# Computed p-values for k=124
# Computed p-values for k=125
# Computed p-values for k=126
# Computed p-values for k=127
# Computed p-values for k=128
# Computed p-values for k=129
# Computed p-values for k=130
# Computed p-values for k=131
# Computed p-values for k=132
# Computed p-values for k=133
# Computed p-values for k=134
# Computed p-values for k=135
# Computed p-values for k=136
# Computed p-values for k=137
# Computed p-values for k=138
# Computed p-values for k=139
# Computed p-values for k=140
# Computed p-values for k=141
# Computed p-values for k=142
# Computed p-values for k=143
# Computed p-values for k=144
# Computed p-values for k=145
# Computed p-values for k=146
# Computed p-values for k=147
# Computed p-values for k=148
# Computed p-values for k=149
# Computed p-values for k=150
# Computed p-values for k=151
# Computed p-values for k=152
# Computed p-values for k=153
# Computed p-values for k=154
# Computed p-values for k=155
# Computed p-values for k=156
# Computed p-values for k=157
# Computed p-values for k=158
# Computed p-values for k=159
# Computed p-values for k=160
# Computed p-values for k=161
# Computed p-values for k=162
# Computed p-values for k=163
# Computed p-values for k=164
# Computed p-values for k=165
# Computed p-values for k=166
# Computed p-values for k=167
# Computed p-values for k=168
# Computed p-values for k=169
# Computed p-values for k=170
# Computed p-values for k=171
# Computed p-values for k=172
# Computed p-values for k=173
# Computed p-values for k=174
# Computed p-values for k=175
# Computed p-values for k=176
# Computed p-values for k=177
# Computed p-values for k=178
# Computed p-values for k=179
# Computed p-values for k=180
# Computed p-values for k=181
# Computed p-values for k=182
# Computed p-values for k=183
# Computed p-values for k=184
# Computed p-values for k=185
# Computed p-values for k=186
# Computed p-values for k=187
# Computed p-values for k=188
# Computed p-values for k=189
# Computed p-values for k=190
# Computed p-values for k=191
# Computed p-values for k=192
# Computed p-values for k=193
# Computed p-values for k=194
# Computed p-values for k=195
# Computed p-values for k=196
# Computed p-values for k=197
# Computed p-values for k=198
# Computed p-values for k=199
# Computed p-values for k=200
# Computed p-values for k=201
# Computed p-values for k=202
# Computed p-values for k=203
# Computed p-values for k=204
# Computed p-values for k=205
# Computed p-values for k=206
# Computed p-values for k=207
# Computed p-values for k=208
# Computed p-values for k=209
# Computed p-values for k=210
# Computed p-values for k=211
# Computed p-values for k=212
# Computed p-values for k=213
# Computed p-values for k=214
# Computed p-values for k=215
# Computed p-values for k=216
# Computed p-values for k=217
# Computed p-values for k=218
# Computed p-values for k=219
# Computed p-values for k=220
# Computed p-values for k=221
# Computed p-values for k=222
# Computed p-values for k=223
# Computed p-values for k=224
# Computed p-values for k=225
# Computed p-values for k=226
# Computed p-values for k=227
# Computed p-values for k=228
# Computed p-values for k=229
# Computed p-values for k=230
# Computed p-values for k=231
# Computed p-values for k=232
# Computed p-values for k=233
# Computed p-values for k=234
# Computed p-values for k=235
# Computed p-values for k=236
# Computed p-values for k=237
# Computed p-values for k=238
# Computed p-values for k=239
# Computed p-values for k=240
# Computed p-values for k=241
# Computed p-values for k=242
# Computed p-values for k=243
# Computed p-values for k=244
# Computed p-values for k=245
# Computed p-values for k=246
# Computed p-values for k=247
# Computed p-values for k=248
# Computed p-values for k=249
# Computed p-values for k=250
# Computed p-values for k=251
# Computed p-values for k=252
# Computed p-values for k=253
# Computed p-values for k=254
# Computed p-values for k=255
# Computed p-values for k=256
# Computed p-values for k=257
# Computed p-values for k=258
# Computed p-values for k=259
# Computed p-values for k=260
# Computed p-values for k=261
# Computed p-values for k=262
# Computed p-values for k=263
# Computed p-values for k=264
# Computed p-values for k=265
# Computed p-values for k=266
# Computed p-values for k=267
# Computed p-values for k=268
# Computed p-values for k=269
# Computed p-values for k=270
# Computed p-values for k=271
# Computed p-values for k=272
# Computed p-values for k=273
# Computed p-values for k=274
# Computed p-values for k=275
# Computed p-values for k=276
# Computed p-values for k=277
# Computed p-values for k=278
# Computed p-values for k=279
# Computed p-values for k=280
# Computed p-values for k=281
# Computed p-values for k=282
# Computed p-values for k=283
# Computed p-values for k=284
# Computed p-values for k=285
# Computed p-values for k=286
# Computed p-values for k=287
# Computed p-values for k=288
# Computed p-values for k=289
# Computed p-values for k=290
# Computed p-values for k=291
# Computed p-values for k=292
# Computed p-values for k=293
# Computed p-values for k=294
# Computed p-values for k=295
# Computed p-values for k=296
# Computed p-values for k=297
# Computed p-values for k=298
# Computed p-values for k=299
# Computed p-values for k=300
# Computed p-values for k=301
# Computed p-values for k=302
# Computed p-values for k=303
# Computed p-values for k=304
# Computed p-values for k=305
# Computed p-values for k=306
# Computed p-values for k=307
# Computed p-values for k=308
# Computed p-values for k=309
# Computed p-values for k=310
# Computed p-values for k=311
# Computed p-values for k=312
# Computed p-values for k=313
# Computed p-values for k=314
# Computed p-values for k=315
# Computed p-values for k=316
# Computed p-values for k=317
# Computed p-values for k=318
# Computed p-values for k=319
# Computed p-values for k=320
# Computed p-values for k=321
# Computed p-values for k=322
# Computed p-values for k=323
# Computed p-values for k=324
# Computed p-values for k=325
# Computed p-values for k=326
# Computed p-values for k=327
# Computed p-values for k=328
# Computed p-values for k=329
# Computed p-values for k=330
# Computed p-values for k=331
# Computed p-values for k=332
# Computed p-values for k=333
# Computed p-values for k=334
# Computed p-values for k=335
# Computed p-values for k=336
# Computed p-values for k=337
# Computed p-values for k=338
# Computed p-values for k=339
# Computed p-values for k=340
# Computed p-values for k=341
# Computed p-values for k=342
# Computed p-values for k=343
# Computed p-values for k=344
# Computed p-values for k=345
# Computed p-values for k=346
# Computed p-values for k=347
# Computed p-values for k=348
# Computed p-values for k=349
# Computed p-values for k=350
# Computed p-values for k=351
# Computed p-values for k=352
# Computed p-values for k=353
# Computed p-values for k=354
# Computed p-values for k=355
# Computed p-values for k=356
# Computed p-values for k=357
# Computed p-values for k=358
# Computed p-values for k=359
# Computed p-values for k=360
# Computed p-values for k=361
# Computed p-values for k=362
# Computed p-values for k=363
# Computed p-values for k=364
# Computed p-values for k=365
# Computed p-values for k=366
# Computed p-values for k=367
# Computed p-values for k=368
# Computed p-values for k=369
# Computed p-values for k=370
# Computed p-values for k=371
# Computed p-values for k=372
# Computed p-values for k=373
# Computed p-values for k=374
# Computed p-values for k=375
# Computed p-values for k=376
# Computed p-values for k=377
# Computed p-values for k=378
# Computed p-values for k=379
# Computed p-values for k=380
# Computed p-values for k=381
# Computed p-values for k=382
# Computed p-values for k=383
# Computed p-values for k=384
# Computed p-values for k=385
# Computed p-values for k=386
# Computed p-values for k=387
# Computed p-values for k=388
# Computed p-values for k=389
# Computed p-values for k=390
# Computed p-values for k=391
# Computed p-values for k=392
# Computed p-values for k=393
# Computed p-values for k=394
# Computed p-values for k=395
# Computed p-values for k=396
# Computed p-values for k=397
# Computed p-values for k=398
# Computed p-values for k=399
# Computed p-values for k=400
# Computed p-values for k=401
# Computed p-values for k=402
# Computed p-values for k=403
# Computed p-values for k=404
# Computed p-values for k=405
# Computed p-values for k=406
# Computed p-values for k=407
# Computed p-values for k=408
# Computed p-values for k=409
# Computed p-values for k=410
# Computed p-values for k=411
# Computed p-values for k=412
# Computed p-values for k=413
# Computed p-values for k=414
# Computed p-values for k=415
# Computed p-values for k=416
# Computed p-values for k=417
# Computed p-values for k=418
# Computed p-values for k=419
# Computed p-values for k=420
# Computed p-values for k=421
# Computed p-values for k=422
# Computed p-values for k=423
# Computed p-values for k=424
# Computed p-values for k=425
# Computed p-values for k=426
# Computed p-values for k=427
# Computed p-values for k=428
# Computed p-values for k=429
# Computed p-values for k=430
# Computed p-values for k=431
# Computed p-values for k=432
# Computed p-values for k=433
# Computed p-values for k=434
# Computed p-values for k=435
# Computed p-values for k=436
# Computed p-values for k=437
# Computed p-values for k=438
# Computed p-values for k=439
# Computed p-values for k=440
# Computed p-values for k=441
# Computed p-values for k=442
# Computed p-values for k=443
# Computed p-values for k=444
# Computed p-values for k=445
# Computed p-values for k=446
# Computed p-values for k=447
# Computed p-values for k=448
# Computed p-values for k=449
# Computed p-values for k=450
# Computed p-values for k=451
# Computed p-values for k=452
# Computed p-values for k=453
# Computed p-values for k=454
# Computed p-values for k=455
# Computed p-values for k=456
# Computed p-values for k=457
# Computed p-values for k=458
# Computed p-values for k=459
# Computed p-values for k=460
# Computed p-values for k=461
# Computed p-values for k=462
# Computed p-values for k=463
# Computed p-values for k=464
# Computed p-values for k=465
# Computed p-values for k=466
# Computed p-values for k=467
# Computed p-values for k=468
# Computed p-values for k=469
# Computed p-values for k=470
# Computed p-values for k=471
# Computed p-values for k=472
# Computed p-values for k=473
# Computed p-values for k=474
# Computed p-values for k=475
# Computed p-values for k=476
# Computed p-values for k=477
# Computed p-values for k=478
# Computed p-values for k=479
# Computed p-values for k=480
# Computed p-values for k=481
# Computed p-values for k=482
# Computed p-values for k=483
# Computed p-values for k=484
# Computed p-values for k=485
# Computed p-values for k=486
# Computed p-values for k=487
# Computed p-values for k=488
# Computed p-values for k=489
# Computed p-values for k=490
# Computed p-values for k=491
# Computed p-values for k=492
# Computed p-values for k=493
# Computed p-values for k=494
# Computed p-values for k=495
# Computed p-values for k=496
# Computed p-values for k=497
# Computed p-values for k=498
# Computed p-values for k=499
# Compute underdensities
# Validation size is:  50000
# Computed p-values for k=20
# Computed p-values for k=21
# Computed p-values for k=22
# Computed p-values for k=23
# Computed p-values for k=24
# Computed p-values for k=25
# Computed p-values for k=26
# Computed p-values for k=27
# Computed p-values for k=28
# Computed p-values for k=29
# Computed p-values for k=30
# Computed p-values for k=31
# Computed p-values for k=32
# Computed p-values for k=33
# Computed p-values for k=34
# Computed p-values for k=35
# Computed p-values for k=36
# Computed p-values for k=37
# Computed p-values for k=38
# Computed p-values for k=39
# Computed p-values for k=40
# Computed p-values for k=41
# Computed p-values for k=42
# Computed p-values for k=43
# Computed p-values for k=44
# Computed p-values for k=45
# Computed p-values for k=46
# Computed p-values for k=47
# Computed p-values for k=48
# Computed p-values for k=49
# Computed p-values for k=50
# Computed p-values for k=51
# Computed p-values for k=52
# Computed p-values for k=53
# Computed p-values for k=54
# Computed p-values for k=55
# Computed p-values for k=56
# Computed p-values for k=57
# Computed p-values for k=58
# Computed p-values for k=59
# Computed p-values for k=60
# Computed p-values for k=61
# Computed p-values for k=62
# Computed p-values for k=63
# Computed p-values for k=64
# Computed p-values for k=65
# Computed p-values for k=66
# Computed p-values for k=67
# Computed p-values for k=68
# Computed p-values for k=69
# Computed p-values for k=70
# Computed p-values for k=71
# Computed p-values for k=72
# Computed p-values for k=73
# Computed p-values for k=74
# Computed p-values for k=75
# Computed p-values for k=76
# Computed p-values for k=77
# Computed p-values for k=78
# Computed p-values for k=79
# Computed p-values for k=80
# Computed p-values for k=81
# Computed p-values for k=82
# Computed p-values for k=83
# Computed p-values for k=84
# Computed p-values for k=85
# Computed p-values for k=86
# Computed p-values for k=87
# Computed p-values for k=88
# Computed p-values for k=89
# Computed p-values for k=90
# Computed p-values for k=91
# Computed p-values for k=92
# Computed p-values for k=93
# Computed p-values for k=94
# Computed p-values for k=95
# Computed p-values for k=96
# Computed p-values for k=97
# Computed p-values for k=98
# Computed p-values for k=99
# Computed p-values for k=100
# Computed p-values for k=101
# Computed p-values for k=102
# Computed p-values for k=103
# Computed p-values for k=104
# Computed p-values for k=105
# Computed p-values for k=106
# Computed p-values for k=107
# Computed p-values for k=108
# Computed p-values for k=109
# Computed p-values for k=110
# Computed p-values for k=111
# Computed p-values for k=112
# Computed p-values for k=113
# Computed p-values for k=114
# Computed p-values for k=115
# Computed p-values for k=116
# Computed p-values for k=117
# Computed p-values for k=118
# Computed p-values for k=119
# Computed p-values for k=120
# Computed p-values for k=121
# Computed p-values for k=122
# Computed p-values for k=123
# Computed p-values for k=124
# Computed p-values for k=125
# Computed p-values for k=126
# Computed p-values for k=127
# Computed p-values for k=128
# Computed p-values for k=129
# Computed p-values for k=130
# Computed p-values for k=131
# Computed p-values for k=132
# Computed p-values for k=133
# Computed p-values for k=134
# Computed p-values for k=135
# Computed p-values for k=136
# Computed p-values for k=137
# Computed p-values for k=138
# Computed p-values for k=139
# Computed p-values for k=140
# Computed p-values for k=141
# Computed p-values for k=142
# Computed p-values for k=143
# Computed p-values for k=144
# Computed p-values for k=145
# Computed p-values for k=146
# Computed p-values for k=147
# Computed p-values for k=148
# Computed p-values for k=149
# Computed p-values for k=150
# Computed p-values for k=151
# Computed p-values for k=152
# Computed p-values for k=153
# Computed p-values for k=154
# Computed p-values for k=155
# Computed p-values for k=156
# Computed p-values for k=157
# Computed p-values for k=158
# Computed p-values for k=159
# Computed p-values for k=160
# Computed p-values for k=161
# Computed p-values for k=162
# Computed p-values for k=163
# Computed p-values for k=164
# Computed p-values for k=165
# Computed p-values for k=166
# Computed p-values for k=167
# Computed p-values for k=168
# Computed p-values for k=169
# Computed p-values for k=170
# Computed p-values for k=171
# Computed p-values for k=172
# Computed p-values for k=173
# Computed p-values for k=174
# Computed p-values for k=175
# Computed p-values for k=176
# Computed p-values for k=177
# Computed p-values for k=178
# Computed p-values for k=179
# Computed p-values for k=180
# Computed p-values for k=181
# Computed p-values for k=182
# Computed p-values for k=183
# Computed p-values for k=184
# Computed p-values for k=185
# Computed p-values for k=186
# Computed p-values for k=187
# Computed p-values for k=188
# Computed p-values for k=189
# Computed p-values for k=190
# Computed p-values for k=191
# Computed p-values for k=192
# Computed p-values for k=193
# Computed p-values for k=194
# Computed p-values for k=195
# Computed p-values for k=196
# Computed p-values for k=197
# Computed p-values for k=198
# Computed p-values for k=199
# Computed p-values for k=200
# Computed p-values for k=201
# Computed p-values for k=202
# Computed p-values for k=203
# Computed p-values for k=204
# Computed p-values for k=205
# Computed p-values for k=206
# Computed p-values for k=207
# Computed p-values for k=208
# Computed p-values for k=209
# Computed p-values for k=210
# Computed p-values for k=211
# Computed p-values for k=212
# Computed p-values for k=213
# Computed p-values for k=214
# Computed p-values for k=215
# Computed p-values for k=216
# Computed p-values for k=217
# Computed p-values for k=218
# Computed p-values for k=219
# Computed p-values for k=220
# Computed p-values for k=221
# Computed p-values for k=222
# Computed p-values for k=223
# Computed p-values for k=224
# Computed p-values for k=225
# Computed p-values for k=226
# Computed p-values for k=227
# Computed p-values for k=228
# Computed p-values for k=229
# Computed p-values for k=230
# Computed p-values for k=231
# Computed p-values for k=232
# Computed p-values for k=233
# Computed p-values for k=234
# Computed p-values for k=235
# Computed p-values for k=236
# Computed p-values for k=237
# Computed p-values for k=238
# Computed p-values for k=239
# Computed p-values for k=240
# Computed p-values for k=241
# Computed p-values for k=242
# Computed p-values for k=243
# Computed p-values for k=244
# Computed p-values for k=245
# Computed p-values for k=246
# Computed p-values for k=247
# Computed p-values for k=248
# Computed p-values for k=249
# Computed p-values for k=250
# Computed p-values for k=251
# Computed p-values for k=252
# Computed p-values for k=253
# Computed p-values for k=254
# Computed p-values for k=255
# Computed p-values for k=256
# Computed p-values for k=257
# Computed p-values for k=258
# Computed p-values for k=259
# Computed p-values for k=260
# Computed p-values for k=261
# Computed p-values for k=262
# Computed p-values for k=263
# Computed p-values for k=264
# Computed p-values for k=265
# Computed p-values for k=266
# Computed p-values for k=267
# Computed p-values for k=268
# Computed p-values for k=269
# Computed p-values for k=270
# Computed p-values for k=271
# Computed p-values for k=272
# Computed p-values for k=273
# Computed p-values for k=274
# Computed p-values for k=275
# Computed p-values for k=276
# Computed p-values for k=277
# Computed p-values for k=278
# Computed p-values for k=279
# Computed p-values for k=280
# Computed p-values for k=281
# Computed p-values for k=282
# Computed p-values for k=283
# Computed p-values for k=284
# Computed p-values for k=285
# Computed p-values for k=286
# Computed p-values for k=287
# Computed p-values for k=288
# Computed p-values for k=289
# Computed p-values for k=290
# Computed p-values for k=291
# Computed p-values for k=292
# Computed p-values for k=293
# Computed p-values for k=294
# Computed p-values for k=295
# Computed p-values for k=296
# Computed p-values for k=297
# Computed p-values for k=298
# Computed p-values for k=299
# Computed p-values for k=300
# Computed p-values for k=301
# Computed p-values for k=302
# Computed p-values for k=303
# Computed p-values for k=304
# Computed p-values for k=305
# Computed p-values for k=306
# Computed p-values for k=307
# Computed p-values for k=308
# Computed p-values for k=309
# Computed p-values for k=310
# Computed p-values for k=311
# Computed p-values for k=312
# Computed p-values for k=313
# Computed p-values for k=314
# Computed p-values for k=315
# Computed p-values for k=316
# Computed p-values for k=317
# Computed p-values for k=318
# Computed p-values for k=319
# Computed p-values for k=320
# Computed p-values for k=321
# Computed p-values for k=322
# Computed p-values for k=323
# Computed p-values for k=324
# Computed p-values for k=325
# Computed p-values for k=326
# Computed p-values for k=327
# Computed p-values for k=328
# Computed p-values for k=329
# Computed p-values for k=330
# Computed p-values for k=331
# Computed p-values for k=332
# Computed p-values for k=333
# Computed p-values for k=334
# Computed p-values for k=335
# Computed p-values for k=336
# Computed p-values for k=337
# Computed p-values for k=338
# Computed p-values for k=339
# Computed p-values for k=340
# Computed p-values for k=341
# Computed p-values for k=342
# Computed p-values for k=343
# Computed p-values for k=344
# Computed p-values for k=345
# Computed p-values for k=346
# Computed p-values for k=347
# Computed p-values for k=348
# Computed p-values for k=349
# Computed p-values for k=350
# Computed p-values for k=351
# Computed p-values for k=352
# Computed p-values for k=353
# Computed p-values for k=354
# Computed p-values for k=355
# Computed p-values for k=356
# Computed p-values for k=357
# Computed p-values for k=358
# Computed p-values for k=359
# Computed p-values for k=360
# Computed p-values for k=361
# Computed p-values for k=362
# Computed p-values for k=363
# Computed p-values for k=364
# Computed p-values for k=365
# Computed p-values for k=366
# Computed p-values for k=367
# Computed p-values for k=368
# Computed p-values for k=369
# Computed p-values for k=370
# Computed p-values for k=371
# Computed p-values for k=372
# Computed p-values for k=373
# Computed p-values for k=374
# Computed p-values for k=375
# Computed p-values for k=376
# Computed p-values for k=377
# Computed p-values for k=378
# Computed p-values for k=379
# Computed p-values for k=380
# Computed p-values for k=381
# Computed p-values for k=382
# Computed p-values for k=383
# Computed p-values for k=384
# Computed p-values for k=385
# Computed p-values for k=386
# Computed p-values for k=387
# Computed p-values for k=388
# Computed p-values for k=389
# Computed p-values for k=390
# Computed p-values for k=391
# Computed p-values for k=392
# Computed p-values for k=393
# Computed p-values for k=394
# Computed p-values for k=395
# Computed p-values for k=396
# Computed p-values for k=397
# Computed p-values for k=398
# Computed p-values for k=399
# Computed p-values for k=400
# Computed p-values for k=401
# Computed p-values for k=402
# Computed p-values for k=403
# Computed p-values for k=404
# Computed p-values for k=405
# Computed p-values for k=406
# Computed p-values for k=407
# Computed p-values for k=408
# Computed p-values for k=409
# Computed p-values for k=410
# Computed p-values for k=411
# Computed p-values for k=412
# Computed p-values for k=413
# Computed p-values for k=414
# Computed p-values for k=415
# Computed p-values for k=416
# Computed p-values for k=417
# Computed p-values for k=418
# Computed p-values for k=419
# Computed p-values for k=420
# Computed p-values for k=421
# Computed p-values for k=422
# Computed p-values for k=423
# Computed p-values for k=424
# Computed p-values for k=425
# Computed p-values for k=426
# Computed p-values for k=427
# Computed p-values for k=428
# Computed p-values for k=429
# Computed p-values for k=430
# Computed p-values for k=431
# Computed p-values for k=432
# Computed p-values for k=433
# Computed p-values for k=434
# Computed p-values for k=435
# Computed p-values for k=436
# Computed p-values for k=437
# Computed p-values for k=438
# Computed p-values for k=439
# Computed p-values for k=440
# Computed p-values for k=441
# Computed p-values for k=442
# Computed p-values for k=443
# Computed p-values for k=444
# Computed p-values for k=445
# Computed p-values for k=446
# Computed p-values for k=447
# Computed p-values for k=448
# Computed p-values for k=449
# Computed p-values for k=450
# Computed p-values for k=451
# Computed p-values for k=452
# Computed p-values for k=453
# Computed p-values for k=454
# Computed p-values for k=455
# Computed p-values for k=456
# Computed p-values for k=457
# Computed p-values for k=458
# Computed p-values for k=459
# Computed p-values for k=460
# Computed p-values for k=461
# Computed p-values for k=462
# Computed p-values for k=463
# Computed p-values for k=464
# Computed p-values for k=465
# Computed p-values for k=466
# Computed p-values for k=467
# Computed p-values for k=468
# Computed p-values for k=469
# Computed p-values for k=470
# Computed p-values for k=471
# Computed p-values for k=472
# Computed p-values for k=473
# Computed p-values for k=474
# Computed p-values for k=475
# Computed p-values for k=476
# Computed p-values for k=477
# Computed p-values for k=478
# Computed p-values for k=479
# Computed p-values for k=480
# Computed p-values for k=481
# Computed p-values for k=482
# Computed p-values for k=483
# Computed p-values for k=484
# Computed p-values for k=485
# Computed p-values for k=486
# Computed p-values for k=487
# Computed p-values for k=488
# Computed p-values for k=489
# Computed p-values for k=490
# Computed p-values for k=491
# Computed p-values for k=492
# Computed p-values for k=493
# Computed p-values for k=494
# Computed p-values for k=495
# Computed p-values for k=496
# Computed p-values for k=497
# Computed p-values for k=498
# Computed p-values for k=499
# Computing unique elements for quantile/s.
# The smallest value of Upsilon_star_plus is less than the smallest key in unique_elements_dict.
# Max Upsilon remained: 241.44258350024586
# Max Upsilon remained: 235.83822100787953
# Max Upsilon remained: 233.72170158382878
# Max Upsilon remained: 230.62450206734732
# Max Upsilon remained: 227.86379664122583
# Max Upsilon remained: 226.9276768328896
# Max Upsilon remained: 224.30738422278435
# Max Upsilon remained: 223.94168645701149
# Max Upsilon remained: 219.95124551755205
# Max Upsilon remained: 216.6300169213357
# Max Upsilon remained: 216.01372399053648
# Max Upsilon remained: 216.01372399053648
# Max Upsilon remained: 215.45099422031996
# Max Upsilon remained: 211.65711394571323
# Max Upsilon remained: 209.82172067561544
# Max Upsilon remained: 206.18650742688683
# Max Upsilon remained: 197.2154530222427
# Max Upsilon remained: 195.0868408230057
# Max Upsilon remained: 194.49016023455988
# Max Upsilon remained: 191.03558795672643
# Max Upsilon remained: 190.60726198877254
# Max Upsilon remained: 190.57319859996144
# Max Upsilon remained: 189.85082289004623
# Max Upsilon remained: 188.35081431879104
# Max Upsilon remained: 184.4373051097417
# Max Upsilon remained: 183.97285897083054
# Max Upsilon remained: 181.87228913749823
# Max Upsilon remained: 179.68142905670194
# Max Upsilon remained: 177.56725664373428
# Max Upsilon remained: 177.54371608072
# Max Upsilon remained: 175.47365729529946
# Max Upsilon remained: 173.4003051894129
# Max Upsilon remained: 171.6777597746397
# Max Upsilon remained: 171.34688622780916
# Max Upsilon remained: 169.38460020000795
# Max Upsilon remained: 168.74317131481797
# Max Upsilon remained: 166.73098193776474
# Max Upsilon remained: 164.31519740575345
# Max Upsilon remained: 161.36854224553693
# Max Upsilon remained: 159.95207455037095
# Max Upsilon remained: 156.08165858452358
# Max Upsilon remained: 152.51105168628646
# Max Upsilon remained: 149.99512316901263
# Max Upsilon remained: 148.8664692638577
# Max Upsilon remained: 147.5975045964114
# Max Upsilon remained: 145.55397877673218
# Max Upsilon remained: 144.7150901964055
# Max Upsilon remained: 143.25719838674365
# Max Upsilon remained: 142.65101274524673
# Max Upsilon remained: 142.5942104678061
# Max Upsilon remained: 139.85387489498615
# Max Upsilon remained: 138.16457297336422
# Max Upsilon remained: 137.4925376385242
# Max Upsilon remained: 132.37152631185066
# Max Upsilon remained: 130.912304649517
# Max Upsilon remained: 130.69490372060224
# Max Upsilon remained: 130.69490372060224
# Max Upsilon remained: 129.8649521494643
# Max Upsilon remained: 129.0332099672325
# Max Upsilon remained: 127.47744724085864
# Max Upsilon remained: 127.38629409520027
# Max Upsilon remained: 125.23980170608404
# Max Upsilon remained: 123.62439302711262
# Max Upsilon remained: 123.53676287824983
# Max Upsilon remained: 123.32373136216684
# Max Upsilon remained: 119.98969331152894
# Max Upsilon remained: 119.89729184312698
# Max Upsilon remained: 119.43571680435916
# Max Upsilon remained: 119.36836172596861
# Max Upsilon remained: 118.86374417623566
# Max Upsilon remained: 117.85575529317877
# Max Upsilon remained: 117.03047154610398
# Max Upsilon remained: 116.3068731039514
# Max Upsilon remained: 115.2606080858455
# Max Upsilon remained: 114.7260668714015
# Max Upsilon remained: 113.45849545832279
# Max Upsilon remained: 113.2059519215533
# Max Upsilon remained: 113.2059519215533
# Max Upsilon remained: 112.71101483640086
# Max Upsilon remained: 111.71958146687274
# Max Upsilon remained: 111.69929636081172
# Max Upsilon remained: 110.52145516348149
# Max Upsilon remained: 109.59360851068598
# Max Upsilon remained: 108.72590510912154
# Max Upsilon remained: 107.25894676572923
# Max Upsilon remained: 107.22055372227882
# Max Upsilon remained: 105.89485845840659
# Max Upsilon remained: 103.92672852894658
# Max Upsilon remained: 103.75055748567134
# Max Upsilon remained: 102.74539575617905
# Max Upsilon remained: 102.45796362286589
# Max Upsilon remained: 102.42834410149212
# Max Upsilon remained: 101.52021218128971
# Max Upsilon remained: 100.99925248571708
# Max Upsilon remained: 100.11729433335051
# Max Upsilon remained: 98.72688692264929
# Max Upsilon remained: 96.90511203443413
# Max Upsilon remained: 96.41882541587172
# Max Upsilon remained: 94.62979436612822
# Max Upsilon remained: 94.12496226733657
# Max Upsilon remained: 93.28850548421077
# Max Upsilon remained: 92.32084233788379
# Max Upsilon remained: 91.95927496277234
# Max Upsilon remained: 91.56937928240971
# Max Upsilon remained: 91.50147507456244
# Max Upsilon remained: 90.6420179179909
# Max Upsilon remained: 90.18674212245487
# Max Upsilon remained: 89.33665118989185
# Max Upsilon remained: 88.88390567118267
# Max Upsilon remained: 88.76588742864396
# Max Upsilon remained: 88.04309329472824
# Max Upsilon remained: 86.76126437910506
# Max Upsilon remained: 85.81268705667533
# Max Upsilon remained: 84.60141344455197
# Max Upsilon remained: 83.78991992685471
# Max Upsilon remained: 83.78991992685471
# Max Upsilon remained: 82.98537651340308
# Max Upsilon remained: 82.38715487748834
# Max Upsilon remained: 81.66710260441863
# Max Upsilon remained: 81.40406240494706
# Max Upsilon remained: 81.1143019370841
# Max Upsilon remained: 80.52536831003547
# Max Upsilon remained: 80.35405044285376
# Max Upsilon remained: 79.31232227352181
# Max Upsilon remained: 78.70740886186294
# Max Upsilon remained: 76.91979832241397
# Max Upsilon remained: 76.06621294192652
# Max Upsilon remained: 74.79042307686832
# Max Upsilon remained: 74.57158307193951
# Max Upsilon remained: 73.31556421502238
# Max Upsilon remained: 73.08005386365926
# Max Upsilon remained: 72.99465070187739
# Max Upsilon remained: 72.57600207230188
# Max Upsilon remained: 72.15798460899104
# Max Upsilon remained: 71.10500549633119
# Max Upsilon remained: 70.49228494610979
# Max Upsilon remained: 70.47037540940129
# Max Upsilon remained: 70.2381557414433
# Max Upsilon remained: 69.59461525141374
# Max Upsilon remained: 69.55088250396805
# Max Upsilon remained: 69.18386603374758
# Max Upsilon remained: 68.9140112216355
# Max Upsilon remained: 68.25991727232537
# Max Upsilon remained: 67.78767275640638
# Max Upsilon remained: 67.57025438849874
# Max Upsilon remained: 67.37525361750015
# Max Upsilon remained: 66.86841811305813
# Max Upsilon remained: 66.86601157471547
# Max Upsilon remained: 66.73316500695012
# Max Upsilon remained: 66.69440661854573
# Max Upsilon remained: 66.32704253914639
# Max Upsilon remained: 65.81051599008724
# Max Upsilon remained: 65.75251688676856
# Max Upsilon remained: 64.7093182086948
# Max Upsilon remained: 64.41130123393395
# Max Upsilon remained: 63.47754640394893
# Max Upsilon remained: 63.47754640394893
# Max Upsilon remained: 62.600026977771755
# Max Upsilon remained: 62.42605642821373
# Max Upsilon remained: 62.42605642821373
# Max Upsilon remained: 61.384875899793066
# Max Upsilon remained: 61.24026137118622
# Max Upsilon remained: 60.85295867447817
# Max Upsilon remained: 60.63973499989211
# Max Upsilon remained: 60.35395284318583
# Max Upsilon remained: 59.966553306022135
# Max Upsilon remained: 59.333236176646885
# Max Upsilon remained: 58.322675691918775
# Max Upsilon remained: 57.94068426500018
# Max Upsilon remained: 57.41696926386014
# Max Upsilon remained: 55.5066075484924
# Max Upsilon remained: 55.2778381250692
# Max Upsilon remained: 55.179572364877316
# Max Upsilon remained: 54.79877144860068
# Max Upsilon remained: 54.51035290848597
# Max Upsilon remained: 54.38102088911919
# Max Upsilon remained: 53.42051741135776
# Max Upsilon remained: 53.00856712610754
# Max Upsilon remained: 52.58542118492876
# Max Upsilon remained: 51.915308368305354
# Max Upsilon remained: 51.768086831503126
# Max Upsilon remained: 51.73945786409782
# Max Upsilon remained: 51.22194558430442
# Max Upsilon remained: 50.831554135349535
# Max Upsilon remained: 49.72268816640155
# Max Upsilon remained: 48.80556286262043
# Max Upsilon remained: 48.765201646811455
# Max Upsilon remained: 48.25232610135047
# Max Upsilon remained: 48.0569427596456
# Max Upsilon remained: 48.0569427596456
# Max Upsilon remained: 47.16059595337414
# Max Upsilon remained: 46.62201450991855
# Max Upsilon remained: 46.30044636325963
# Max Upsilon remained: 46.08823117567385
# Max Upsilon remained: 46.08823117567385
# Max Upsilon remained: 45.157767378356766
# Max Upsilon remained: 44.910060818376266
# Max Upsilon remained: 44.727010332583774
# Max Upsilon remained: 44.351325776342584
# Max Upsilon remained: 44.351325776342584
# Max Upsilon remained: 43.68260697820323
# Max Upsilon remained: 43.49707790877848
# Max Upsilon remained: 43.49707790877848
# Max Upsilon remained: 43.20652541530531
# Max Upsilon remained: 43.03096917472692
# Max Upsilon remained: 42.863764452957675
# Max Upsilon remained: 42.53202488964266
# Max Upsilon remained: 42.44084444272762
# Max Upsilon remained: 42.08913537526666
# Max Upsilon remained: 41.84071629254346
# Max Upsilon remained: 41.81680182627163
# Max Upsilon remained: 41.150664680309106
# Max Upsilon remained: 40.99069935266131
# Max Upsilon remained: 40.99069935266131
# Max Upsilon remained: 40.31778704608742
# Max Upsilon remained: 40.17390535828666
# Max Upsilon remained: 39.984760070514135
# Max Upsilon remained: 39.52208739361235
# Max Upsilon remained: 39.366384104799685
# Max Upsilon remained: 38.72029142417793
# Max Upsilon remained: 38.3985794486577
# Max Upsilon remained: 38.34151108235209
# Max Upsilon remained: 38.25188971190326
# Max Upsilon remained: 37.8943968026689
# Max Upsilon remained: 37.890155293643105
# Max Upsilon remained: 37.60891809522111
# Max Upsilon remained: 37.248249851914395
# Max Upsilon remained: 37.0784232253423
# Max Upsilon remained: 36.999107343477185
# Max Upsilon remained: 36.999107343477185
# Max Upsilon remained: 36.999107343477185
# Max Upsilon remained: 36.999107343477185
# Max Upsilon remained: 36.5134534260213
# Max Upsilon remained: 36.46269526369145
# Max Upsilon remained: 35.812289886414
# Max Upsilon remained: 35.5156399743293
# Max Upsilon remained: 35.463839017368734
# Max Upsilon remained: 34.84941317606696
# Max Upsilon remained: 34.71404856184824
# Max Upsilon remained: 34.50590626729052
# Max Upsilon remained: 34.40786779279737
# Max Upsilon remained: 34.06899074916361
# Max Upsilon remained: 34.00445890176849
# Max Upsilon remained: 33.90821160736582
# Max Upsilon remained: 33.41872534403156
# Max Upsilon remained: 33.23591482678393
# Max Upsilon remained: 32.935563906033806
# Max Upsilon remained: 32.65134161619348
# Max Upsilon remained: 32.51032418698168
# Max Upsilon remained: 31.499185526489406
# Max Upsilon remained: 31.20769695356478
# Max Upsilon remained: 31.085940711599875
# Max Upsilon remained: 30.927132698822444
# Max Upsilon remained: 30.658396603048423
# Max Upsilon remained: 30.503818620353623
# Max Upsilon remained: 30.347012222534538
# Max Upsilon remained: 30.04134945032586
# Max Upsilon remained: 29.83106470684726
# Max Upsilon remained: 29.752738925716756
# Max Upsilon remained: 29.411442615585198
# Max Upsilon remained: 29.295482170988773
# Max Upsilon remained: 29.1267923130235
# Max Upsilon remained: 29.065769843263258
# Max Upsilon remained: 28.78115672397302
# Max Upsilon remained: 28.45155138665823
# Max Upsilon remained: 27.92089200064644
# Max Upsilon remained: 27.735282141309302
# Max Upsilon remained: 27.67990664350873
# Max Upsilon remained: 27.67990664350873
# Max Upsilon remained: 27.520589833402862
# Max Upsilon remained: 27.4487428713966
# Max Upsilon remained: 27.275659006421563
# Max Upsilon remained: 27.21594519571936
# Max Upsilon remained: 26.751284997595008
# Max Upsilon remained: 26.680530897030295
# Max Upsilon remained: 26.662261765763496
# Max Upsilon remained: 26.644006671776296
# Max Upsilon remained: 26.633876492377723
# Max Upsilon remained: 26.438148776042855
# Max Upsilon remained: 26.406958507916777
# Max Upsilon remained: 26.335994538547176
# Max Upsilon remained: 25.984328481583866
# Max Upsilon remained: 25.96638034639816
# Max Upsilon remained: 25.76958362584207
# Max Upsilon remained: 25.368217698141812
# Max Upsilon remained: 25.30210420585139
# Max Upsilon remained: 25.112530679152506
# Max Upsilon remained: 25.09145226015572
# Max Upsilon remained: 24.584115595351594
# Max Upsilon remained: 24.580056927985087
# Max Upsilon remained: 24.442305281932374
# Max Upsilon remained: 24.230607274443273
# Max Upsilon remained: 23.959298112411755
# Max Upsilon remained: 23.90023996996186
# Max Upsilon remained: 23.77199362533119
# Max Upsilon remained: 23.762781472581608
# Max Upsilon remained: 23.383342962846722
# Max Upsilon remained: 23.2966476510542
# Max Upsilon remained: 23.12458270233685
# Max Upsilon remained: 22.930439639331695
# Max Upsilon remained: 22.84978971325265
# Max Upsilon remained: 22.80179481453586
# Max Upsilon remained: 22.705824921099968
# Max Upsilon remained: 22.381790294899705
# Max Upsilon remained: 22.261545116949254
# Max Upsilon remained: 22.153777796192447
# Max Upsilon remained: 21.93946236933095
# Max Upsilon remained: 21.92578345290525
# Max Upsilon remained: 21.760020065297986
# Max Upsilon remained: 21.736868959136714
# Max Upsilon remained: 21.41854599342319
# Max Upsilon remained: 21.343247605687115
# Max Upsilon remained: 21.27326628444075
# Max Upsilon remained: 21.105558977295694
# Max Upsilon remained: 20.967397303259215
# Max Upsilon remained: 20.95079106482652
# Max Upsilon remained: 20.707338254852445
# Max Upsilon remained: 20.557062182199886
# Max Upsilon remained: 20.540042778975362
# Max Upsilon remained: 20.245801958643103
# Max Upsilon remained: 20.230055874422867
# Max Upsilon remained: 19.983682253272548
# Max Upsilon remained: 19.78713512707015
# Max Upsilon remained: 19.548660030329355
# Max Upsilon remained: 19.506884344232773
# Max Upsilon remained: 19.294399461196868
# Max Upsilon remained: 19.27019361996235
# Max Upsilon remained: 19.206572830890984
# Max Upsilon remained: 18.990216380729773
# Max Upsilon remained: 18.800256319377613
# Max Upsilon remained: 18.680207720526347
# Max Upsilon remained: 18.540226628586364
# Max Upsilon remained: 18.297939297779916
# Max Upsilon remained: 18.232041887594672
# Max Upsilon remained: 17.777142355488785
# Max Upsilon remained: 17.713360927457153
# Max Upsilon remained: 17.66693435545551
# Max Upsilon remained: 17.44008084712118
# Max Upsilon remained: 17.264683653662612
# Max Upsilon remained: 17.004083347003718
# Max Upsilon remained: 16.981539219542352
# Max Upsilon remained: 16.967258140320183
# Max Upsilon remained: 16.842457704018006
# Max Upsilon remained: 16.743487896854603
# Max Upsilon remained: 16.619362322470433
# Max Upsilon remained: 16.542355108584502
# Max Upsilon remained: 16.520927108909493
# Max Upsilon remained: 16.301242255133285
# Max Upsilon remained: 15.866725427757514
# Max Upsilon remained: 15.793633651314506
# Max Upsilon remained: 15.788597073246073
# Max Upsilon remained: 15.508970515423867
# Max Upsilon remained: 15.344202209426713
# Max Upsilon remained: 15.251524213860954
# Max Upsilon remained: 15.249237972318797
# Max Upsilon remained: 15.195119115940436
# Max Upsilon remained: 15.139632631202186
# Max Upsilon remained: 14.87892810405473
# Max Upsilon remained: 14.875817197862109
# Max Upsilon remained: 14.774731198448485
# Max Upsilon remained: 14.705886437333815
# Max Upsilon remained: 14.506049712194192
# Max Upsilon remained: 14.313646623561347
# Max Upsilon remained: 13.908917471379343
# Max Upsilon remained: 13.700267567125431
# Max Upsilon remained: 13.558500991885579
# Max Upsilon remained: 13.415852855895313
# Max Upsilon remained: 13.415852855895313
# Max Upsilon remained: 13.399307870235873
# Max Upsilon remained: 13.377219922779556
# Max Upsilon remained: 13.313140569771765
# Max Upsilon remained: 13.31108504298445
# Max Upsilon remained: 13.187844662771427
# Max Upsilon remained: 13.100114217336262
# Max Upsilon remained: 13.060336852348335
# Max Upsilon remained: 13.024800783431008
# Max Upsilon remained: 13.019254310010194
# Max Upsilon remained: 12.979096170256875
# Max Upsilon remained: 12.865089038471192
# Max Upsilon remained: 12.650008778431545
# Max Upsilon remained: 12.550401188235375
# Max Upsilon remained: 12.18658438320521
# Max Upsilon remained: 12.110109122750641
# Max Upsilon remained: 11.963781260296173
# The smallest value of Upsilon_star_plus is less than the smallest key in unique_elements_dict.
# Max Upsilon remained: 324.2120441495792
# Max Upsilon remained: 183.96024512995405
# Max Upsilon remained: 126.34216277873934
# Max Upsilon remained: 110.71289682286147
# Max Upsilon remained: 99.13076271030815
# Max Upsilon remained: 82.31663381297756
# Max Upsilon remained: 81.6140198547566
# Max Upsilon remained: 71.58244422493848
# Max Upsilon remained: 64.78422374784016
# Max Upsilon remained: 63.98536076410474
# Max Upsilon remained: 61.03220839303693
# Max Upsilon remained: 56.82565311240224
# Max Upsilon remained: 50.65675333984465
# Max Upsilon remained: 49.7198941309424
# Max Upsilon remained: 47.19054188823038
# Max Upsilon remained: 46.360965619411196
# Max Upsilon remained: 32.43037050964566
# Max Upsilon remained: 31.83832063506272
# Max Upsilon remained: 31.24756207707454
# Max Upsilon remained: 29.587560888844376
# Max Upsilon remained: 25.359251067161765
# Max Upsilon remained: 23.79254000856276
# Max Upsilon remained: 20.749487816249612
# Max Upsilon remained: 15.993164665332706
# Max Upsilon remained: 14.174422422435258
# Max Upsilon remained: 12.411863771450122
# Max Upsilon remained: 11.950385547731372
# Max Upsilon remained: 11.88562039271263
# Max Upsilon remained: 11.55376348043541
#
# Shapes of result_dict keys:
# Key                            Shape
# ---------------------------------------------
# Upsilon_star_plus              (2,)
# Upsilon_star_minus             (2,)
# critical_quantiles             (2,)
# Upsilon_i_plus_null            (450000,)
# Upsilon_i_minus_null           (450000,)
# stats                          dict
#   Upsilon_i_minus              (50000,)
#   kstar_minus                  (50000,)
#   Upsilon_i_plus               (50000,)
#   kstar_plus                   (50000,)
#   Upsilon_i_Val_minus          (50000,)
#   kstar_Val_minus              (50000,)
#   Upsilon_i_Val_plus           (50000,)
#   kstar_Val_plus               (50000,)
# stats_reverse                  dict
#   Upsilon_i_minus              (50000,)
#   kstar_minus                  (50000,)
#   Upsilon_i_plus               (50000,)
#   kstar_plus                   (50000,)
#   Upsilon_i_Val_minus          (50000,)
#   kstar_Val_minus              (50000,)
#   Upsilon_i_Val_plus           (50000,)
#   kstar_Val_plus               (50000,)
# unique_elements_overdensities  dict
#   249.12624823625876           (21,)
#   235.83822100787953           (5,)
#   233.72170158382878           (17,)
#   230.62450206734732           (4,)
#   227.86379664122583           (1,)
#   226.9276768328896            (13,)
#   224.30738422278435           (26,)
#   223.94168645701149           (35,)
#   219.95124551755205           (5,)
#   216.6300169213357            (1,)
#   216.01372399053648           (98,)
#   215.45099422031996           (1,)
#   211.65711394571323           (21,)
#   209.82172067561544           (8,)
#   206.18650742688683           (50,)
#   197.2154530222427            (12,)
#   195.0868408230057            (17,)
#   194.49016023455988           (11,)
#   191.03558795672643           (2,)
#   190.60726198877254           (87,)
#   190.57319859996144           (1,)
#   189.85082289004623           (9,)
#   188.35081431879104           (32,)
#   184.4373051097417            (5,)
#   183.97285897083054           (12,)
#   181.87228913749823           (6,)
#   179.68142905670194           (4,)
#   177.56725664373428           (1,)
#   177.54371608072              (1,)
#   175.47365729529946           (22,)
# ...
#   119.89729184312698           (1,)
#   119.43571680435916           (12,)
#   119.36836172596861           (93,)
#   118.86374417623566           (1,)
#   117.85575529317877           (2,)
#   117.03047154610398           (21,)
#   116.3068731039514            (39,)
#   115.2606080858455            (1,)
#   114.7260668714015            (1,)
#   113.45849545832279           (2,)
#   113.2059519215533            (35,)
#   112.71101483640086           (1,)
#   111.71958146687274           (1,)
#   111.69929636081172           (2,)
#   110.52145516348149           (17,)
#   109.59360851068598           (14,)
#   108.72590510912154           (2,)
#   107.25894676572923           (28,)
#   107.22055372227882           (3,)
#   105.89485845840659           (8,)
#   103.92672852894658           (2,)
#   103.75055748567134           (2,)
#   102.74539575617905           (22,)
#   102.45796362286589           (1,)
#   102.42834410149212           (7,)
#   101.52021218128971           (22,)
#   100.99925248571708           (4,)
#   100.11729433335051           (53,)
#   98.72688692264929            (17,)
#   96.90511203443413            (31,)
#   96.41882541587172            (7,)
#   94.62979436612822            (8,)
#   94.12496226733657            (2,)
#   93.28850548421077            (1,)
#   92.32084233788379            (4,)
#   91.95927496277234            (2,)
#   91.56937928240971            (1,)
#   91.50147507456244            (7,)
#   90.6420179179909             (2,)
#   90.18674212245487            (3,)
#   89.33665118989185            (12,)
#   88.88390567118267            (20,)
#   88.76588742864396            (46,)
#   88.04309329472824            (3,)
#   86.76126437910506            (27,)
#   85.81268705667533            (16,)
#   84.60141344455197            (8,)
#   83.78991992685471            (3,)
#   82.98537651340308            (1,)
#   82.38715487748834            (6,)
#   81.66710260441863            (8,)
#   81.40406240494706            (30,)
#   81.1143019370841             (1,)
#   80.52536831003547            (28,)
#   80.35405044285376            (37,)
#   79.31232227352181            (3,)
#   78.70740886186294            (7,)
#   76.91979832241397            (1,)
#   76.06621294192652            (7,)
#   74.79042307686832            (12,)
#   74.57158307193951            (18,)
#   73.31556421502238            (5,)
#   73.08005386365926            (4,)
#   72.99465070187739            (6,)
#   72.57600207230188            (3,)
#   72.15798460899104            (27,)
#   71.10500549633119            (1,)
#   70.49228494610979            (14,)
#   70.47037540940129            (2,)
#   70.2381557414433             (4,)
#   69.59461525141374            (3,)
#   69.55088250396805            (11,)
#   69.18386603374758            (5,)
#   68.9140112216355             (18,)
#   68.25991727232537            (1,)
#   67.78767275640638            (1,)
#   67.57025438849874            (1,)
#   67.37525361750015            (2,)
#   66.86841811305813            (1,)
#   66.86601157471547            (1,)
#   66.73316500695012            (1,)
#   66.69440661854573            (8,)
#   66.32704253914639            (1,)
#   65.81051599008724            (7,)
#   65.75251688676856            (21,)
#   64.7093182086948             (7,)
#   64.41130123393395            (4,)
#   63.47754640394893            (3,)
#   62.600026977771755           (1,)
#   62.42605642821373            (12,)
#   61.384875899793066           (1,)
#   61.24026137118622            (12,)
#   60.85295867447817            (9,)
#   60.63973499989211            (33,)
#   60.35395284318583            (48,)
#   59.966553306022135           (55,)
#   59.333236176646885           (11,)
#   58.322675691918775           (1,)
#   57.94068426500018            (5,)
#   57.41696926386014            (17,)
#   55.5066075484924             (1,)
#   55.2778381250692             (1,)
#   55.179572364877316           (2,)
#   54.79877144860068            (4,)
#   54.51035290848597            (1,)
#   54.38102088911919            (5,)
#   53.42051741135776            (40,)
#   53.00856712610754            (6,)
#   52.58542118492876            (2,)
#   51.915308368305354           (43,)
#   51.768086831503126           (35,)
#   51.73945786409782            (18,)
#   51.22194558430442            (1,)
#   50.831554135349535           (17,)
#   49.72268816640155            (4,)
#   48.80556286262043            (1,)
#   48.765201646811455           (1,)
#   48.25232610135047            (22,)
#   48.0569427596456             (3,)
#   47.16059595337414            (10,)
#   46.62201450991855            (6,)
#   46.30044636325963            (1,)
#   46.08823117567385            (6,)
#   45.157767378356766           (1,)
#   44.910060818376266           (5,)
#   44.727010332583774           (1,)
#   44.351325776342584           (31,)
#   43.68260697820323            (1,)
#   43.49707790877848            (4,)
#   43.20652541530531            (1,)
#   43.03096917472692            (2,)
#   42.863764452957675           (9,)
#   42.53202488964266            (1,)
#   42.44084444272762            (21,)
#   42.08913537526666            (40,)
#   41.84071629254346            (1,)
#   41.81680182627163            (1,)
#   41.150664680309106           (1,)
#   40.99069935266131            (17,)
#   40.31778704608742            (1,)
#   40.17390535828666            (14,)
#   39.984760070514135           (1,)
#   39.52208739361235            (3,)
#   39.366384104799685           (1,)
#   38.72029142417793            (1,)
#   38.3985794486577             (4,)
#   38.34151108235209            (6,)
#   38.25188971190326            (1,)
#   37.8943968026689             (36,)
#   37.890155293643105           (3,)
#   37.60891809522111            (26,)
#   37.248249851914395           (1,)
#   37.0784232253423             (9,)
#   36.999107343477185           (1,)
#   36.5134534260213             (1,)
#   36.46269526369145            (5,)
#   35.812289886414              (13,)
#   35.5156399743293             (48,)
#   35.463839017368734           (7,)
#   34.84941317606696            (3,)
#   34.71404856184824            (2,)
#   34.50590626729052            (32,)
#   34.40786779279737            (1,)
#   34.06899074916361            (12,)
#   34.00445890176849            (1,)
#   33.90821160736582            (19,)
#   33.41872534403156            (1,)
#   33.23591482678393            (8,)
#   32.935563906033806           (5,)
#   32.65134161619348            (5,)
#   32.51032418698168            (7,)
#   31.499185526489406           (1,)
#   31.20769695356478            (13,)
#   31.085940711599875           (1,)
#   30.927132698822444           (2,)
#   30.658396603048423           (8,)
#   30.503818620353623           (8,)
#   30.347012222534538           (7,)
#   30.04134945032586            (1,)
#   29.83106470684726            (1,)
#   29.752738925716756           (9,)
#   29.411442615585198           (2,)
#   29.295482170988773           (1,)
#   29.1267923130235             (4,)
#   29.065769843263258           (1,)
#   28.78115672397302            (37,)
#   28.45155138665823            (1,)
#   27.92089200064644            (1,)
#   27.735282141309302           (2,)
#   27.67990664350873            (2,)
#   27.520589833402862           (1,)
#   27.4487428713966             (1,)
#   27.275659006421563           (5,)
#   27.21594519571936            (4,)
#   26.751284997595008           (1,)
#   26.680530897030295           (1,)
#   26.662261765763496           (22,)
#   26.644006671776296           (1,)
#   26.633876492377723           (13,)
#   26.438148776042855           (1,)
#   26.406958507916777           (7,)
#   26.335994538547176           (1,)
#   25.984328481583866           (1,)
#   25.96638034639816            (12,)
#   25.76958362584207            (7,)
#   25.368217698141812           (6,)
#   25.30210420585139            (2,)
#   25.112530679152506           (2,)
#   25.09145226015572            (8,)
#   24.584115595351594           (6,)
#   24.580056927985087           (19,)
#   24.442305281932374           (1,)
#   24.230607274443273           (1,)
#   23.959298112411755           (2,)
#   23.90023996996186            (26,)
#   23.77199362533119            (1,)
#   23.762781472581608           (1,)
#   23.383342962846722           (2,)
#   23.2966476510542             (1,)
#   23.12458270233685            (18,)
#   22.930439639331695           (21,)
#   22.84978971325265            (1,)
#   22.80179481453586            (1,)
#   22.705824921099968           (2,)
#   22.381790294899705           (2,)
#   22.261545116949254           (7,)
#   22.153777796192447           (1,)
#   21.93946236933095            (3,)
#   21.92578345290525            (19,)
#   21.760020065297986           (1,)
#   21.736868959136714           (1,)
#   21.41854599342319            (1,)
#   21.343247605687115           (1,)
#   21.27326628444075            (4,)
#   21.105558977295694           (1,)
#   20.967397303259215           (1,)
#   20.95079106482652            (21,)
#   20.707338254852445           (1,)
#   20.557062182199886           (1,)
#   20.540042778975362           (28,)
#   20.245801958643103           (2,)
#   20.230055874422867           (1,)
#   19.983682253272548           (24,)
#   19.78713512707015            (2,)
#   19.548660030329355           (23,)
#   19.506884344232773           (2,)
#   19.294399461196868           (8,)
#   19.27019361996235            (12,)
#   19.206572830890984           (1,)
#   18.990216380729773           (20,)
#   18.800256319377613           (1,)
#   18.680207720526347           (1,)
#   18.540226628586364           (3,)
#   18.297939297779916           (8,)
#   18.232041887594672           (2,)
#   17.777142355488785           (2,)
#   17.713360927457153           (5,)
#   17.66693435545551            (3,)
#   17.44008084712118            (3,)
#   17.264683653662612           (10,)
#   17.004083347003718           (5,)
#   16.981539219542352           (6,)
#   16.967258140320183           (1,)
#   16.842457704018006           (7,)
#   16.743487896854603           (3,)
#   16.619362322470433           (6,)
#   16.542355108584502           (1,)
#   16.520927108909493           (40,)
#   16.301242255133285           (3,)
#   15.866725427757514           (16,)
#   15.793633651314506           (1,)
#   15.788597073246073           (25,)
#   15.508970515423867           (1,)
#   15.344202209426713           (1,)
#   15.251524213860954           (6,)
#   15.249237972318797           (3,)
#   15.195119115940436           (56,)
#   15.139632631202186           (1,)
#   14.87892810405473            (1,)
#   14.875817197862109           (16,)
#   14.774731198448485           (1,)
#   14.705886437333815           (15,)
#   14.506049712194192           (9,)
#   14.313646623561347           (2,)
#   13.908917471379343           (3,)
#   13.700267567125431           (3,)
#   13.558500991885579           (1,)
#   13.415852855895313           (1,)
#   13.399307870235873           (1,)
#   13.377219922779556           (32,)
#   13.313140569771765           (1,)
#   13.31108504298445            (1,)
#   13.187844662771427           (16,)
#   13.100114217336262           (3,)
#   13.060336852348335           (7,)
#   13.024800783431008           (35,)
#   13.019254310010194           (2,)
#   12.979096170256875           (10,)
#   12.865089038471192           (9,)
#   12.650008778431545           (23,)
#   12.550401188235375           (19,)
#   12.18658438320521            (1,)
#   12.110109122750641           (9,)
#   11.963781260296173           (1,)
# unique_elements_underdensities dict
#   345.8804430994127            (704,)
#   183.96024512995405           (81,)
#   126.34216277873934           (51,)
#   110.71289682286147           (33,)
#   99.13076271030815            (43,)
#   82.31663381297756            (1,)
#   81.6140198547566             (20,)
#   71.58244422493848            (34,)
#   64.78422374784016            (1,)
#   63.98536076410474            (12,)
#   61.03220839303693            (13,)
#   56.82565311240224            (18,)
#   50.65675333984465            (11,)
#   49.7198941309424             (9,)
#   47.19054188823038            (37,)
#   46.360965619411196           (112,)
#   32.43037050964566            (1,)
#   31.83832063506272            (1,)
#   31.24756207707454            (1,)
#   29.587560888844376           (27,)
#   25.359251067161765           (90,)
#   23.79254000856276            (5,)
#   20.749487816249612           (19,)
#   15.993164665332706           (15,)
#   14.174422422435258           (23,)
#   12.411863771450122           (2,)
#   11.950385547731372           (3,)
#   11.88562039271263            (1,)
#   11.55376348043541            (1,)
# overdensities                  dict
#   0.9999                       (3817,)
#   0.99999                      (3629,)
# underdensities                 dict
#   0.9999                       (1364,)
#   0.99999                      (1339,)

# %% [markdown]
# #### Overdensities test_set:
# result_dictionary['stats']['Upsilon_i_plus'] : $\Upsilon_i, i\in \mathbf{Y} $
#
# #### Underdensities reference_set:
# result_dictionary['stats']['Upsilon_i_Val_plus'] : $\Upsilon_i, i\in \mathbf{X} $ (the IV one)
#
# #### Overdensities reference_set:
# result_dictionary['stats_reverse']['Upsilon_i_plus'] : $\Upsilon_j(rev), j\in \mathbf{X} $
#
# #### Underdensities test_set:
# result_dictionary['stats_reverse']['Upsilon_i_Val_plus'] : $\Upsilon_j(rev), j\in \mathbf{Y} $ (the IV one)

# %% [markdown]
# ### 2.1 Visualize the putative anomalous points

# %% [markdown]
# Plot values marked as putative anomalies.
#
# The overdensities within the test dataset are colored based on their $\Upsilon_i $ with red cmap.
#
# The overdensities within the reference dataset are colored based on their $\Upsilon_i(rev) $ with blue cmap.

# %%
from utils_37 import     plot_data_points_marked_as_putative_anomalies


plot_data_points_marked_as_putative_anomalies(test_data, reference_data, result_dictionary )

# %% [markdown]
# ## 3 Iterative Equalization

# %% [markdown]
# Pipeline for
# #### Overdensities test_set:
# result_dictionary['stats']['Upsilon_i_plus'] : $\Upsilon_i, i\in \mathbf{Y}$;
#
# 1) While $\exists i \in \mathbf{Y}$ such that $\Upsilon_i \geq \Upsilon_*$;
#
# 2) Identify the index $i_{max}$ such that maximize $\Upsilon_{i_{max}} = \max_{i\in \mathbf{Y}}{\Upsilon_i}$;
#
# 3) Remove $i_{\text{max}}$ and its nearest neighbours up to the next $\mathbf{X}$ data point from the set $\mathbf{Y}$. Store all removed points in a new set $\mathbf{W_o}$. Update the set $\mathbf{U} = \mathbf{U} \setminus \mathbf{W_o}$;
#
# 4)  Recompute $\Upsilon_i, i\in \mathbf{Y}$ for the remaining points in $\mathbf{Y}$ that still exceed $\Upsilon_*$, restricting the nearest-neighbour search to updated $\mathbf{U}$ that do not include points in $\mathbf{W_o}$.
#
# 5) Return to point 1)
#
# Pipeline for
# #### Overdensities reference_set:
# result_dictionary['stats_reverse']['Upsilon_i_plus'] : $\Upsilon_j(rev), j\in \mathbf{X} $
#
# 1) While $\exists j \in \mathbf{X}$ such that $\Upsilon_j(rev) \geq \Upsilon_*$;
#
# 2) Identify the index $j_{max}$ such that maximize $\Upsilon_{j_{max}}(rev) = \max_{j\in \mathbf{X}}{\Upsilon_j}(rev)$;
#
# 3) Remove $j_{\text{max}}$ and its nearest neighbours up to the next $\mathbf{Y}$ data point from the set $\mathbf{X}$. Store all removed points in a new set $\mathbf{W_u}$. Update the set $\mathbf{U} = \mathbf{U} \setminus \mathbf{W_u}$;
#
# 4)  Recompute $\Upsilon_j(rev), j\in \mathbf{X}$ for the remaining points in $\mathbf{X}$ that still exceed $\Upsilon_*$, restricting the nearest-neighbour search to updated $\mathbf{U}$ that do not include points in $\mathbf{W_u}$.
#
# 5) Return to point 1)

# %% [markdown]
# ### 3.1 Visualize $\mathbf{W_o}$ and $\mathbf{W_u}$

# %% [markdown]
# Plot values marked extracted by iterative equalization.
#
# The overdensities within the test dataset $\mathbf{W_o}$ are colored in red.
#
# The overdensities within the reference dataset $\mathbf{W_u}$ are colored blue.

# %%
from utils_37 import     plot_points_extracted_by_iterative_equalization
qt = 1 # which of the given quantiles to consider
plot_points_extracted_by_iterative_equalization( test_data, reference_data, result_dictionary, threshold=CRITICAL_QUANTILES[qt] )

# %% [markdown]
# ## 4 Clustering and aggregating

# %% [markdown]
# In order to get statistics from our computaitons let us partition the datapoints such that $\Upsilon_i, i\in \mathbf{Y}$ and $\Upsilon_j(res), j\in \mathbf{X}$ that were inititaly greater then $\Upsilon_*$:
#
# #### Overdensities test_set:
# result_dictionary['stats']['Upsilon_i_plus'] : $\Upsilon_i, i\in \mathbf{Y} $
#
# #### Overdensities reference_set:
# result_dictionary['stats_reverse']['Upsilon_i_plus'] : $\Upsilon_j(rev), j\in \mathbf{X} $

# %% [markdown]
# ### 4.1 Intersect the thus obtained clusters with $\mathbf{W_o}$ and $\mathbf{W_u}$

# %% [markdown]
# #### 4.1.1 Overdensities test:

# %% [markdown]
# ##### 1) Within each overdensity cluster identify the $i_{loc}$ such that $\Upsilon_{i_{loc}} = \min_{i \in \mathbf{W_o}}\Upsilon_{i} $

# %% [markdown]
# ##### 2) Within each overdensity cluster keep all points such that $\Upsilon_{i} >= \Upsilon_{i_{loc}}, i\in \mathbf{U}$.

# %% [markdown]
# ##### 3) Get the desired statistics by separatelly considering those comming fom \mathbf{X} (background whithin that cluster) and those comming from \mathbf{Y}.

# %% [markdown]
# #### 4.1.2 :Overdensities reference (underdensities):

# %% [markdown]
# ##### 1) Within each overdensity cluster identify the $j_{loc}$ such that $\Upsilon_{j_{loc}}(rev) = \min_{j \in \mathbf{W_u}}\Upsilon_{j}(rev) $

# %% [markdown]
# ##### 2) Within each overdensity cluster keep all points such that $\Upsilon_{j}(rev) >= \Upsilon_{j_{loc}}(rev), j\in \mathbf{U}$.

# %% [markdown]
# ##### 3) Get the desired statistics by separatelly considering those comming fom \mathbf{Y} (test underdensities belonging to that cluster) and those comming from \mathbf{X}.

# %%
#%% # Clustering

clusters = EagleEye_v7.partitian_function(reference_data,test_data,result_dictionary,result_dictionary['Upsilon_star_plus'][qt], result_dictionary['Upsilon_star_minus'][qt],K_M=K_M)

#clusters_plus,clusters_minus = clusters
# Out:
# Computation of distances started
# Computation of the distances up to 500 NNs started
# 0.42 seconds for computing distances
# ID estimation finished: selecting ID of [2.95]
# kstar estimation started, Dthr = 23.92812698
# 0.02 seconds computing kstar
# kstar-NN density estimation started
# k-NN density estimation finished
# Clustering started
# init succeded
# Raw identification of the putative centers:  0.000 sec
# Further checking on centers:  0.002 sec
# Pruning of the centers wrongly identified in part one:  0.000 sec
# Preliminary assignation finished:  0.005 sec
# ('Number of clusters before multimodality test=', 7)
# Identification of the saddle points:  0.011 sec
# Multimodality test finished:  0.000 sec
# Final operations: 0.0003533363342285156 sec
# Clustering finished, 7 clusters found
# total time is, 0.019446372985839844
# Computation of distances started
# Computation of the distances up to 500 NNs started
# 0.11 seconds for computing distances
# ID estimation finished: selecting ID of [2.87]
# kstar estimation started, Dthr = 23.92812698
# 0.01 seconds computing kstar
# kstar-NN density estimation started
# k-NN density estimation finished
# Clustering started
# init succeded
# Raw identification of the putative centers:  0.000 sec
# Further checking on centers:  0.000 sec
# Pruning of the centers wrongly identified in part one:  0.000 sec
# Preliminary assignation finished:  0.002 sec
# ('Number of clusters before multimodality test=', 7)
# Identification of the saddle points:  0.004 sec
# Multimodality test finished:  0.000 sec
# Final operations: 0.0001246929168701172 sec
# Clustering finished, 3 clusters found
# total time is, 0.007060527801513672

# %%
clusters_plus,clusters_minus = clusters
clusters_minus
# Out:
# [array([  916,  1021,  1515,  1686,  3570,  3627,  3758,  3921,  4636,
#          4779,  4794,  5148,  5159,  8180,  8426,  9081,  9200,  9367,
#         10157, 10439, 11492, 12299, 12545, 14286, 14609, 14787, 15131,
#         15667, 15688, 15781, 16682, 16865, 17806, 18421, 18939, 19247,
#         20418, 20583, 20789, 21299, 21878, 22335, 23203, 23254, 23750,
#         24239, 24768, 24809, 25850, 26549, 27219, 28035, 28654, 29566,
#         29632, 30392, 30868, 30953, 31084, 32356, 32580, 33898, 35066,
#         35171, 35238, 36510, 36718, 37026, 37089, 38057, 38684, 39034,
#         39197, 39791, 40226, 40230, 40252, 40426, 40462, 40763, 40806,
#         40856, 41919, 42785, 43047, 43686, 43806, 44463, 45228, 45396,
#         45534, 45762, 45992, 46105, 46363, 46820, 50111, 50355, 51442,
#         51664, 53635, 53755, 53853, 56605, 57001, 57432, 57551, 60137,
#         60259, 60271, 60537, 60881, 61084, 61582, 61762, 61772, 63273,
#         63388, 63615, 64820, 67982, 68046, 68182, 68464, 68632, 68666,
#         68785, 69400, 69482, 69963, 69975, 70834, 71294, 71474, 71565,
#         71661, 73280, 75142, 75339, 75441, 75442, 75693, 76162, 76191,
#         76220, 77157, 78219, 78372, 79137, 80031, 80338, 80457, 80774,
#         82407, 82898, 82915, 84529, 84557, 84980, 84981, 85201, 85558,
#         85784, 85994, 86229, 86538, 86543, 86675, 86715, 86998, 87193,
#         87268, 88025, 88377, 88957, 90131, 91344, 91483, 91645, 92230,
#         92521, 92918, 93593, 94418, 94751, 95093, 95190, 96937, 96986,
#         98900, 98901, 98902, 98903, 98904, 98905, 98906, 98907, 98908,
#         98909, 98910, 98911, 98912, 98913, 98914, 98915, 98916, 98917,
#         98918, 98919, 98920, 98921, 98922, 98923, 98924, 98925, 98926,
#         98927, 98928, 98929, 98930, 98931, 98932, 98933, 98934, 98935,
#         98936, 98937, 98938, 98939, 98940, 98941, 98942, 98943, 98944,
#         98945, 98946, 98947, 98948, 98949, 98950, 98951, 98952, 98953,
#         98954, 98955, 98956, 98957, 98958, 98959, 98960, 98961, 98962,
#         98963, 98964, 98965, 98966, 98967, 98968, 98969, 98970, 98971,
#         98972, 98973, 98974, 98975, 98976, 98977, 98978, 98979, 98980,
#         98981, 98982, 98983, 98984, 98985, 98986, 98987, 98988, 98989,
#         98990, 98991, 98992, 98993, 98994, 98995, 98996, 98997, 98998,
#         98999]),
#  array([  167,   229,   361,   504,  1013,  1038,  1364,  1648,  1958,
#          2074,  2596,  2774,  2955,  3600,  3875,  4059,  4149,  4610,
#          5169,  5286,  5293,  5635,  5780,  5990,  6116,  6145,  6213,
#          6405,  6611,  6762,  7030,  7121,  7792,  8168,  8539,  8664,
#          8696,  8727,  8922,  9043,  9254,  9330,  9365,  9501,  9688,
#          9806,  9848,  9999, 10127, 10247, 10250, 10307, 10467, 10470,
#         11450, 12090, 12281, 12504, 12763, 12853, 13029, 13116, 13480,
#         13593, 13626, 14024, 14274, 14403, 14421, 14628, 15019, 15564,
#         15619, 15622, 15868, 15917, 15919, 16388, 16419, 17472, 17503,
#         17511, 17634, 18053, 18462, 18604, 18680, 18813, 18839, 18985,
#         19015, 19023, 19048, 19136, 19315, 19445, 19586, 19728, 19798,
#         19916, 20042, 20154, 20728, 20739, 21195, 21438, 21562, 21588,
#         21657, 21702, 21752, 21753, 21804, 22206, 22288, 22635, 22658,
#         22881, 23372, 23591, 23769, 23881, 24199, 24521, 24541, 24592,
#         24609, 24707, 24728, 24870, 24919, 25082, 25490, 25671, 25830,
#         25950, 25985, 26102, 26155, 26193, 26292, 26496, 26946, 27228,
#         27336, 27520, 27524, 27695, 27823, 27946, 28009, 28096, 28206,
#         28384, 28441, 28461, 28496, 28825, 29102, 29154, 29554, 29708,
#         30433, 30559, 30617, 30789, 31457, 31465, 31806, 31939, 32010,
#         32177, 32235, 32335, 32648, 33071, 33712, 33759, 33795, 34186,
#         34274, 34286, 34395, 34467, 34683, 34859, 35079, 35094, 35207,
#         35298, 35641, 35738, 36060, 36115, 36175, 36190, 36272, 36362,
#         36721, 36925, 37025, 37396, 37590, 38119, 38229, 38344, 38539,
#         38612, 39152, 39175, 39208, 39340, 39570, 39638, 39792, 40042,
#         40274, 40298, 40548, 40553, 41154, 41210, 41326, 41637, 41878,
#         42044, 42366, 42415, 42430, 43631, 43702, 44179, 44297, 44376,
#         44559, 45051, 45273, 45723, 46257, 46573, 46623, 46684, 46893,
#         46912, 47167, 50074, 50106, 50415, 50427, 50604, 50817, 50904,
#         50991, 51122, 51236, 51495, 51504, 51783, 52154, 52630, 52705,
#         53005, 53175, 53440, 53445, 53559, 53833, 53902, 54101, 54181,
#         54367, 54503, 54553, 54773, 54979, 55149, 55396, 55881, 56435,
#         56506, 56589, 56672, 56900, 57151, 57188, 57268, 57828, 57856,
#         58330, 58594, 58806, 59030, 59193, 59485, 59564, 59759, 59773,
#         59870, 59936, 59986, 60021, 60120, 60254, 60318, 60447, 60455,
#         60585, 60795, 60814, 60931, 61027, 61032, 61218, 61633, 61713,
#         62460, 62569, 62718, 62831, 62964, 63171, 63445, 63522, 63550,
#         63688, 63820, 63966, 64660, 64742, 64872, 65044, 65483, 66165,
#         66377, 66779, 66847, 67046, 67317, 67466, 67780, 67935, 68205,
#         68428, 68581, 68696, 68833, 68883, 68961, 68997, 69213, 69474,
#         69838, 69867, 69889, 69911, 70399, 70432, 70582, 70686, 70921,
#         71226, 71318, 71457, 71625, 71847, 71865, 72121, 72265, 72439,
#         72463, 72638, 72676, 73309, 73500, 73848, 73879, 73890, 74098,
#         74203, 74424, 74459, 74485, 74564, 74720, 75070, 75186, 75236,
#         75267, 75863, 76037, 76141, 76272, 76365, 76552, 76613, 76890,
#         77174, 77359, 77976, 78109, 78311, 78335, 78399, 78485, 79441,
#         79522, 79665, 79805, 79988, 80148, 80415, 80498, 80670, 81283,
#         81547, 81560, 81893, 81988, 82053, 82524, 82544, 82582, 82618,
#         82653, 82954, 82999, 83008, 83104, 83105, 83325, 83333, 84587,
#         84618, 84667, 84890, 84893, 84954, 85038, 85039, 85646, 85840,
#         85899, 85952, 86037, 86266, 86376, 86381, 86844, 86845, 87143,
#         87149, 87445, 87612, 87620, 87807, 88250, 88263, 88352, 88440,
#         89119, 89282, 89510, 89588, 89814, 89897, 89911, 90300, 90322,
#         90400, 90502, 90542, 90576, 90666, 90780, 90785, 91022, 91060,
#         91378, 91402, 91425, 91574, 91930, 92213, 92295, 92332, 92361,
#         92438, 92639, 92711, 92919, 93069, 93158, 93696, 93901, 93934,
#         94065, 94160, 94176, 94339, 94778, 94779, 94801, 95331, 95522,
#         95650, 95662, 95972, 96425, 96555, 96592, 96720, 96822, 96892,
#         97093, 98108, 98175, 98373, 98549, 98688, 98743, 99000, 99001,
#         99002, 99003, 99004, 99005, 99006, 99007, 99008, 99009, 99010,
#         99011, 99012, 99013, 99014, 99015, 99016, 99017, 99018, 99019,
#         99020, 99021, 99022, 99023, 99024, 99025, 99026, 99027, 99028,
#         99029, 99030, 99031, 99032, 99033, 99034, 99035, 99036, 99037,
#         99038, 99039, 99040, 99041, 99042, 99043, 99044, 99045, 99046,
#         99047, 99048, 99049, 99050, 99051, 99052, 99053, 99054, 99055,
#         99056, 99057, 99058, 99059, 99060, 99061, 99062, 99063, 99064,
#         99065, 99066, 99067, 99068, 99069, 99070, 99071, 99072, 99073,
#         99074, 99075, 99076, 99077, 99078, 99079, 99080, 99081, 99082,
#         99083, 99084, 99085, 99086, 99087, 99088, 99089, 99090, 99091,
#         99092, 99093, 99094, 99095, 99096, 99097, 99098, 99099, 99100,
#         99101, 99102, 99103, 99104, 99105, 99106, 99107, 99108, 99109,
#         99110, 99111, 99112, 99113, 99114, 99115, 99116, 99117, 99118,
#         99119, 99120, 99121, 99122, 99123, 99124, 99125, 99126, 99127,
#         99128, 99129, 99130, 99131, 99132, 99133, 99134, 99135, 99136,
#         99137, 99138, 99139, 99140, 99141, 99142, 99143, 99144, 99145,
#         99146, 99147, 99148, 99149, 99150, 99151, 99152, 99153, 99154,
#         99155, 99156, 99157, 99158, 99159, 99160, 99161, 99162, 99163,
#         99164, 99165, 99166, 99167, 99168, 99169, 99170, 99171, 99172,
#         99173, 99174, 99175, 99176, 99177, 99178, 99179, 99180, 99181,
#         99182, 99183, 99184, 99185, 99186, 99187, 99188, 99189, 99190,
#         99191, 99192, 99193, 99194, 99195, 99196, 99197, 99198, 99199,
#         99200, 99201, 99202, 99203, 99204, 99205, 99206, 99207, 99208,
#         99209, 99210, 99211, 99212, 99213, 99214, 99215, 99216, 99217,
#         99218, 99219, 99220, 99221, 99222, 99223, 99224, 99225, 99226,
#         99227, 99228, 99229, 99230, 99231, 99232, 99233, 99234, 99235,
#         99236, 99237, 99238, 99239, 99240, 99241, 99242, 99243, 99244,
#         99245, 99246, 99247, 99248, 99249, 99250, 99251, 99252, 99253,
#         99254, 99255, 99256, 99257, 99258, 99259, 99260, 99261, 99262,
#         99263, 99264, 99265, 99266, 99267, 99268, 99269, 99270, 99271,
#         99272, 99273, 99274, 99275, 99276, 99277, 99278, 99279, 99280,
#         99281, 99282, 99283, 99284, 99285, 99286, 99287, 99288, 99289,
#         99290, 99291, 99292, 99293, 99294, 99295, 99296, 99297, 99298,
#         99299]),
#  array([   13,   150,   480, ..., 99997, 99998, 99999])]

# %%
#%% # Creation of the dictionaries
IV_IE_dict = EagleEye_v7.IV_IE_get_dict(clusters,result_dictionary,[CRITICAL_QUANTILES[qt]],test_data,reference_data)
# Out:
# [21930 29333 43925 ... 48924 48977 49028]
# Number of clusters:  7
# Cluster number  1
# Cluster number  2
# [1691, 47301, 47302, 47304, 47305, 47306, 47307, 47308, 47309, 47310, 47311, 47313, 47314, 47315, 47317, 47318, 47319, 47320, 47321, 47322, 47323, 47324, 47326, 47327, 47328, 47330, 47331, 47332, 47335, 47339, 47340, 47341, 47342, 47344, 47345, 47346, 47347, 47348, 47351, 47352, 47353, 47355, 47357, 47358, 47359, 47360, 47361, 47362, 47363, 47364, 47365, 47366, 47367, 47368, 47369, 47370, 47371, 47372, 47373, 47374, 47375, 47376, 47378, 47379, 47380, 47381, 47382, 47383, 47384, 47385, 47386, 47387, 47388, 3357, 47390, 47391, 47389, 47392, 47394, 47395, 47396, 47397, 47393, 47399, 26419]
# ----------------------------
# [ 1691  3357  6609  6903  7908  7978  8700 10149 10779 12924 13445 13470
#  13477 15654 15953 17763 18350 19024 21102 21647 21793 24495 26176 26419
#  26727 27027 27338 27395 28909 29085 30582 31307 31430 32781 32996 34893
#  35272 35767 36068 36271 36523 37673 40307 42654 43591 43708 44082 46653
#  47030 47300 47301 47302 47303 47304 47305 47306 47307 47308 47309 47310
#  47311 47312 47313 47314 47315 47316 47317 47318 47319 47320 47321 47322
#  47323 47324 47325 47326 47327 47328 47329 47330 47331 47332 47333 47334
#  47335 47336 47337 47338 47339 47340 47341 47342 47343 47344 47345 47346
#  47347 47348 47349 47350 47351 47352 47353 47354 47355 47356 47357 47358
#  47359 47360 47361 47362 47363 47364 47365 47366 47367 47368 47369 47370
#  47371 47372 47373 47374 47375 47376 47377 47378 47379 47380 47381 47382
#  47383 47384 47385 47386 47387 47388 47389 47390 47391 47392 47393 47394
#  47395 47396 47397 47398 47399 50016 52048 52950 53209 53921 54471 55131
#  57764 57940 58841 59141 59249 59620 59859 61462 61742 63450 63701 64623
#  66157 66737 66967 67476 67605 67685 68228 68700 69127 69742 69789 70443
#  70496 70723 70896 72132 72796 74254 74490 74795 75975 77171 77300 77538
#  78315 79133 79416 80652 80922 80927 82409 83608 83626 84774 85085 85358
#  88434 89017 89333 89550 89646 91435 92291 92789 97481 97742 97786 98384]
# Cluster number  3
# Cluster number  4
# Cluster number  5
# Cluster number  6
# Cluster number  7
# Number of clusters:  3

# %% [markdown]
# #### Structure of the dictionary containing the results
#     IV_IE_dict = {
#     "OVER_clusters": {
#         i: {"IE_extra": None, "From_test": None, "From_ref": None}
#         for i in range(len(clusters_plus))
#     },
#     "UNDER_clusters": {
#         i: {"IE_extra": None, "From_test": None, "From_ref": None}
#         for i in range(len(clusters_minus))
#     }
#     }

# %% [markdown]
# ### 4.2 Visualize Clustered Overdensities and Underdensities

# %% [markdown]
# #### 4.2.1 Clustering of points removed by itarative equalization

# %%
from utils_37 import plot_3d_ie_extra

plot_3d_ie_extra(IV_IE_dict, test_data, reference_data)

# %% [markdown]
# #### 4.2.2 Clustering of aggregaed Overdensities wrt test data ( shades of reds ) and reference data (shades of blus)

# %%
from utils_37 import plot_3d_second

# Clustering of anomalous points:
plot_3d_second(IV_IE_dict, test_data, reference_data)

# %% [markdown]
# #### 4.2.3 Clustering of aggregated Underdensities in the test dataset (red) and refereference dataset (blus)

# %%
from utils_37 import plot_3d_third


# Background from the opposite dataset wrt the clustered anomalies:
plot_3d_third(IV_IE_dict, test_data, reference_data)

# %%
from EagleEye_v7 import pval_post_equalization
# get the distribution of Upsilon_i^+
over_clusters = IV_IE_dict.get("OVER_clusters", {})
under_clusters = IV_IE_dict.get("UNDER_clusters", {})

# Suppose these are your arrays of Upsilon_i^+ for all test points and for the "OVER" subset
data_all = result_dictionary['stats']['Upsilon_i_plus']
all_overdensities = [
    idx 
    for cluster_data in over_clusters.values() 
    for idx in cluster_data.get('From_test', [])
]
all_eualized = [x for x in range(test_data.shape[0]) if x not in all_overdensities ]
NUMBER_CORES = 10
PARTITION_SIZE = 100

Upsilon_post_IE = pval_post_equalization(
    test_data, 
    reference_data, 
    all_eualized,
    K_M,
    NUMBER_CORES,
    PARTITION_SIZE
    )

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from utils_37 import get_shades

over_clusters = IV_IE_dict.get("OVER_clusters", {})
under_clusters = IV_IE_dict.get("UNDER_clusters", {})

# Suppose these are your arrays of Upsilon_i^+ for all test points and for the "OVER" subset
data_all = result_dictionary['stats']['Upsilon_i_plus']
all_overdensities = [
    idx 
    for cluster_data in over_clusters.values() 
    for idx in cluster_data.get('From_test', [])
]
data_sub = data_all[all_overdensities]

fig = plt.figure(figsize=(18, 18))
gs = fig.add_gridspec(2, 2, height_ratios=[2, 1])

# 3D subplots (ax0, ax1) ...
ax0 = fig.add_subplot(gs[0, 0], projection='3d')
ax1 = fig.add_subplot(gs[0, 1], projection='3d')
# 1D distribution subplot
ax2 = fig.add_subplot(gs[1, :])

# -------------------------------------------------------------------------
# Then continue with your plotting code exactly as before:
axes = [ax0, ax1, ax2]

#############################################################################
# Everything below remains exactly as you had it (titles, colorbars, etc.)   #
#############################################################################

idx_plot = result_dictionary['stats']['Upsilon_i_plus'] >= result_dictionary['Upsilon_star_plus'][0]
sc1 = axes[0].scatter(
    test_data[idx_plot, 0],
    test_data[idx_plot, 1],
    test_data[idx_plot, 2],
    c=result_dictionary['stats']['Upsilon_i_plus'][idx_plot],
    cmap='autumn_r',
    label='$\\Upsilon_i^+ \geq \\Upsilon_*^+$ in Test',
    alpha=1,
    s=5,
    vmin=0
)

# Colorbar for the first scatter
colorbar1 = fig.colorbar(sc1, ax=axes[0], orientation='horizontal', fraction=0.045, pad=0.04)
colorbar1.set_label('$\\Upsilon_i^+$(test)')

idx_plot2 = result_dictionary['stats_reverse']['Upsilon_i_plus'] >= result_dictionary['Upsilon_star_minus'][0]
sc2 = axes[0].scatter(
    reference_data[idx_plot2, 0],
    reference_data[idx_plot2, 1],
    reference_data[idx_plot2, 2],
    c=result_dictionary['stats_reverse']['Upsilon_i_plus'][idx_plot2],
    label='$\\Upsilon_i^+ \geq \\Upsilon_*^+$ in Reference',
    cmap='winter_r',
    alpha=1,
    s=5,
    vmin=0
)
colorbar2 = fig.colorbar(sc2, ax=axes[1], orientation='horizontal', fraction=0.045, pad=0.04)
colorbar2.set_label('$\\Upsilon_i^+$(ref)')

axes[0].set_xlim(-100, 100)
axes[0].set_ylim(-100, 100)
axes[0].set_zlim(-100, 100)
#axes[0].set_title("$\\Upsilon_i^+ \geq \\Upsilon_*^+$ in Test and Reference ", fontsize=14)
axes[0].legend()
over_clusters = IV_IE_dict.get("OVER_clusters", {})
under_clusters = IV_IE_dict.get("UNDER_clusters", {})

n_over = len(over_clusters)
n_under = len(under_clusters)

over_Reds = get_shades(n_over, 'Reds')
under_Blues = get_shades(n_under, 'Blues')

for idx, (cluster_id, cluster_data) in enumerate(over_clusters.items()):
    row_indices = cluster_data.get("From_test", [])
    if not row_indices:
        continue
    cluster_points = test_data[row_indices]
    xs, ys, zs = cluster_points[:, 0], cluster_points[:, 1], cluster_points[:, 2]
    axes[1].scatter(xs, ys, zs, c=[over_Reds[idx]], marker='.', s=15,
                    label=f"OVER {cluster_id}" if idx == 0 else "")

for idx, (cluster_id, cluster_data) in enumerate(under_clusters.items()):
    row_indices = cluster_data.get("From_ref", [])
    if not row_indices:
        continue
    cluster_points = reference_data[row_indices]
    xs, ys, zs = cluster_points[:, 0], cluster_points[:, 1], cluster_points[:, 2]
    axes[1].scatter(xs, ys, zs, c=[under_Blues[idx]], marker='.', s=15)

#axes[1].set_title("Clustered Anomalies:\n OVER(test) (shades of Red), \n OVER(ref) (shades of Blue)", fontsize=14)
axes[1].set_xlim(-100, 100)
axes[1].set_ylim(-100, 100)
axes[1].set_zlim(-100, 100)
axes[1].legend(['OVER(test) C1','OVER(test) C2','OVER(test) C3','OVER(test) C4','OVER(test) C5','OVER(test) C6','OVER(test) C7','OVER(ref) C1','OVER(ref) C2','OVER(ref) C3'])

# -------------------------------------------------------------------------

# Now let's do the histogram on ax2.
ax2.set_yscale('log')

# --- 1) Plot the navy histogram with Seaborn (all data) ---
sns.histplot(
    data_all,
    bins=70,
    kde=False,
    stat='density',  # important to match the manual density calculation
    label=r'$\Upsilon_i^+$ ',
    color='navy',
    element='step',
    linewidth=2.5,
    alpha=0.6,
    ax=ax2
)

# --- 2) Plot the KDE for the null distribution (optional) ---
sns.kdeplot(
    result_dictionary['Upsilon_i_plus_null'],
    color='limegreen',
    label='null distribution',
    linewidth=4,
    ax=ax2
)
# optional vertical line
ax2.axvline(
    x=result_dictionary['Upsilon_star_plus'][0],
    color='red',
    linestyle='--',
    linewidth=4,
    label=r'$\Upsilon_*^+$'
)

sns.kdeplot(
    Upsilon_post_IE,
    color='magenta',
    linestyle='--',
    label='$\\Upsilon_i^+$ (U\W)',
    linewidth=4,
    ax=ax2
)



# --- 3) Manually compute the fraction-based histogram for the subset ---
# Use the same bins as above for a proper overlay:
num_bins = 70
counts_all, bin_edges = np.histogram(data_all, bins=num_bins)
counts_sub, _         = np.histogram(data_sub, bins=bin_edges)

# compute bin centers and widths for the bar plot
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])
bin_widths  = bin_edges[1:] - bin_edges[:-1]

N_all = len(data_all)
density_all = counts_all / (N_all * bin_widths)

ratio = np.zeros_like(counts_all, dtype=float)
valid = counts_all > 0
ratio[valid] = counts_sub[valid] / counts_all[valid]

# final "fraction-of-navy" density for each bin
density_sub = density_all * ratio  # = counts_sub / (N_all * bin_widths)

# plot these densities as bars
ax2.bar(
    bin_centers,
    density_sub,
    width=bin_widths,
    color='gold',
    alpha=0.5,
    edgecolor='gold',
    linewidth=1.2,
    label='$\\Upsilon_i^+ :OVER(test)$'
)



ax2.set_xlabel(r'$\Upsilon_i$')
ax2.set_ylim([1e-5, 1e0])  # depends on your data
ax2.legend()

plt.tight_layout()


# Adding labels to each subplot

ax0.annotate('A', xy=(0.02, 0.95), xycoords='axes fraction',
            fontsize=21, fontweight='bold', va='top', ha='left')

ax1.annotate('B', xy=(0.02, 0.95), xycoords='axes fraction',
            fontsize=21, fontweight='bold', va='top', ha='left')

ax2.annotate('C', xy=(0.02, 0.95), xycoords='axes fraction',
            fontsize=21, fontweight='bold', va='top', ha='left')

plt.show()
# Out:
# /home/johan/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/johan/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/johan/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
Ups_i_p_navy               = data_all
null_green                 = result_dictionary['Upsilon_i_plus_null']
Ups_s_p_red                = result_dictionary['Upsilon_star_plus'][0]
Ups_i_p_post_IE_magenta    = Upsilon_post_IE
Ups_i_p_post_IE_AG_gold    = data_sub

# %%
import pandas as pd

# Suppose you have the following data:
Ups_i_p_navy = data_all
null_green = result_dictionary['Upsilon_i_plus_null']
Ups_s_p_red = result_dictionary['Upsilon_star_plus'][1]
Ups_i_p_post_IE_magenta = Upsilon_post_IE
Ups_i_p_post_IE_AG_gold = data_sub

# Create a DataFrame from the vectors. 
# pd.Series(...) ensures each list/array is converted to a column with flexible length.
df = pd.DataFrame({
    'Ups_i_p_navy': pd.Series(Ups_i_p_navy),
    'null_green': pd.Series(null_green),
    'Ups_s_p_red': pd.Series(Ups_s_p_red),
    'Ups_i_p_post_IE_magenta': pd.Series(Ups_i_p_post_IE_magenta),
    'Ups_i_p_post_IE_AG_gold': pd.Series(Ups_i_p_post_IE_AG_gold)
})

# Save to CSV
df.to_csv('pannelC.csv', index=False)
print("Data saved to my_vectors.csv")
# Out:
# Data saved to my_vectors.csv

# %%
Ups_s_p_red
# Out:
# 12.038181196579936
